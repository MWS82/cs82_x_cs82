# %% [markdown]
# # X-matching
#
# Here we will test the cross-matching of catalogs using the very same catalog.
# Clearly, the matching with itself will --should-- match the very same object at each position; for this reason --because of the known, trivial result-- we should enjoy the moment to handle pre-/post-processing tasks.
#
# For instance, using the [booq] library we should:
# * plot the data points (i.e, objects) position
# * cutout a region of the sky to sample the dataset
# * shift objects position
# * run the x-match pipeline using different methods
#  * nearest-neighbor
#  * great-circle
#  * "la massa"
#    * plot distances between the matching pairs
#
# [booq]: https://github.com/chbrandt/booq

# %%
import booq

# %% [markdown]
# ## The Data
#
# We are going to use the `cs82` catalog.

# %%
# !ls cs82
# Out:
# changelog.txt	  contents.cfg				   metadata.csv
# columns_all	  CS82 data inspection (incomplete).ipynb  samples
# columns_morphoto  cs82_photoauto.fits
# columns_world	  gavo

# %%
filedata='cs82/cs82_photoauto.fits'
filemeta='cs82/metadata.csv'

# %% [markdown]
# ### As ATable

# %%
from booq.table import ATable
cs82_test = ATable.read(data=filedata, metadata=filemeta, rows=1E4)

# %%
cs82_test.metatable
# Out:
#                           description unit  \
# colname
# OBJID               ObjectID ($index)   --
# ALPHA_J2000           Right Ascencion  deg
# DELTA_J2000               Declination  deg
# MAG_AUTO           Magnitude filter i  mag
# MAGERR_AUTO  Magnitude error filter i  mag
# CLASS_STAR                         --   --
# FLUX_RADIUS                        --   px
# FLAGS           Quality of photometry   --
#
#                                                     ucd    dtype nil
# colname
# OBJID                        ((meta, id), (meta, main))    int64  --
# ALPHA_J2000               ((pos, eq, ra), (meta, main))  float64  --
# DELTA_J2000              ((pos, eq, dec), (meta, main))  float64  --
# MAG_AUTO                    ((phot, mag), (em, opt, I))  float32  --
# MAGERR_AUTO  ((stat, error), (phot, mag), (em, opt, I))  float32  --
# CLASS_STAR                   ((src, class, starGalaxy))  float32  --
# FLUX_RADIUS                ((phot, flux), (em, opt, I))  float32  --
# FLAGS                              ((meta, code, qual))    int16  --

# %%
cs82_test
# Out:
# <ATable length=10000>
#  OBJID     ALPHA_J2000     DELTA_J2000    ...  CLASS_STAR FLUX_RADIUS FLAGS
#                deg             deg        ...                  px
#  int64       float64         float64      ...   float32     float32   int16
# -------- --------------- ---------------- ... ----------- ----------- -----
#     2609 -0.774542651339  -0.971344230377 ...     0.79214     2.79215     0
#     5032  -1.40109155171  -0.940996135742 ...    0.108331     1.60765     0
#     6245 -0.952408197038  -0.924954357991 ...    0.535358     3.69384     2
#     6704  -1.39575648939  -0.918731640744 ...   0.0188971     2.71909     0
#    10481  -1.30100007027  -0.870724049331 ... 0.000140369     4.52054     0
#    12709   -1.3504286251  -0.847851230977 ...    0.122526     2.06206     0
#    17905 -0.542615991536     -0.794216579 ... 0.000394834     3.26503     0
#    21314 -0.684256347819  -0.754340863016 ...    0.396414     2.03572     0
#    22954 -0.906235071321  -0.734063598136 ...   0.0315593      2.6616     0
#      ...             ...              ... ...         ...         ...   ...
# 17397817  -25.0547377849  -0.118141828626 ...    0.716824     2.00714     0
# 9976     2.273076      0
# 9977     1.708551      0
# 9978     3.521010      0
# 9979     3.486969      0
# 9980     3.359077      0
# 9981     3.064404      3
# 9982     3.342379      1
# 9983     1.938532      0
# 9984     3.026269      3
# 9985     2.829615      0
# 9986     2.560337      0
# 9987     2.881177      0
# 9988     1.398024      0
# 9989     5.120473      3
# 9990     2.007138      0
# 9991     4.237621      0
# 9992     2.040721      0
# 9993     2.035710      0
# 9994     2.585194      0
# 9995     3.039368      2
# 9996     2.125433      0
# 9997     2.909278      0
# 9998     3.464548      0
# 9999     2.221648      0
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Plot objects position

# %%
from booq import plot
plot.set_device('notebook')
# Out:
# /home/chbrandt/fido/repos/booq/booq/plot/mybokeh/__init__.py:433: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(False, "Not implemented yet")
# /home/chbrandt/.conda/envs/booq/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)

# %%
from booq.plot import PlotScatter
p = PlotScatter()
ds_label = p.add_dataset(df,label='catalog sample',x='ALPHA_J2000',y='DELTA_J2000')
p.plot(ds_label)
p.show()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7f9f62fe-6b67-4780-9445-d95f63b873cc">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3dcec4b8-02f1-4864-ab90-f1b34a2f6f7e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3dcec4b8-02f1-4864-ab90-f1b34a2f6f7e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3dcec4b8-02f1-4864-ab90-f1b34a2f6f7e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3dcec4b8-02f1-4864-ab90-f1b34a2f6f7e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f9e3222e-a567-4763-b548-ac06369ffc63":{"roots":{"references":[{"attributes":{},"id":"c2c9512e-a15d-4e3c-b6fc-5dcca1706e9e","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"46eee365-3f8a-4741-8daa-81639a18ff99","type":"PanTool"},{"id":"a1955711-8c44-4404-b33c-5b1e29d300d5","type":"BoxZoomTool"},{"id":"7599db2d-67ed-446d-9409-f96870b4098f","type":"WheelZoomTool"},{"id":"c559a626-21aa-4d4c-bfbc-c1fce5f8c97c","type":"ResizeTool"},{"id":"63f4a257-1f7b-4909-a753-983fd0e27523","type":"ResetTool"},{"id":"ee3ce111-a30c-4181-b393-67d9ff5f320b","type":"BoxSelectTool"},{"id":"8d8f5a58-8e00-4d9f-8bdd-dbb0725c8faa","type":"LassoSelectTool"},{"id":"298cd2fc-cb9e-4d12-ad0b-087166e5afec","type":"SaveTool"},{"id":"14845633-dfcd-4664-8847-2be0f977e367","type":"HelpTool"}]},"id":"426d1f1b-0398-4a9e-92c1-f93cf927534c","type":"Toolbar"},{"attributes":{"callback":null},"id":"412b347f-b92e-421a-b139-70290400d709","type":"DataRange1d"},{"attributes":{},"id":"e62a4d67-ffed-42c2-ae85-06235e08dca9","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"ra"},"y":{"field":"dec"}},"id":"0d86b0c7-a04b-4880-a24a-1ae4ab8b2f1d","type":"Circle"},{"attributes":{},"id":"4ac1ba35-b2ec-4eb4-a249-e90271764202","type":"LinearScale"},{"attributes":{"axis_label":"ra","formatter":{"id":"4fc0749a-2ff7-452d-a246-b49a87761919","type":"BasicTickFormatter"},"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"}},"id":"a521d865-a0d3-4ef3-8bc0-ae7d2b8dd1b6","type":"LinearAxis"},{"attributes":{},"id":"4fc0749a-2ff7-452d-a246-b49a87761919","type":"BasicTickFormatter"},{"attributes":{},"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"},{"attributes":{"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"}},"id":"b4f28d54-6f43-44a5-b6c5-6203fa2e2f25","type":"Grid"},{"attributes":{},"id":"60ad5e1d-f21d-4362-a848-80d674c3837f","type":"ToolEvents"},{"attributes":{"axis_label":"dec","formatter":{"id":"e62a4d67-ffed-42c2-ae85-06235e08dca9","type":"BasicTickFormatter"},"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"}},"id":"73edb850-e0b0-486f-847c-2ddb729dc4b5","type":"LinearAxis"},{"attributes":{},"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"}},"id":"8d0e250f-fb27-467d-821e-9d1ee8560118","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c0a71c1c-87f1-4453-aea0-b328e94c0d73","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c42856c8-ba2a-4fc2-b1ca-1a8f57823cde","type":"ColumnDataSource"},"glyph":{"id":"97ea8285-ef7a-41db-983c-88c826eeb58f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0d86b0c7-a04b-4880-a24a-1ae4ab8b2f1d","type":"Circle"},"selection_glyph":null},"id":"ef068c7a-af1c-4950-8a1b-562dbc0b5ec1","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"d862e8c3-bfff-40c1-b090-0404709494ca","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Scatter"},"id":"5b6f1a38-2bbe-4e48-8dbc-628239253d29","type":"Title"},{"attributes" ...

# %% [markdown]
# ## Select a sub-sample
#
# We'll select now a sample based on their position, the goal is to have data points close to each other, to eventually x-match such positions.

# %%
ra = (0,5)
dec= (0,1)
_ir = df.ALPHA_J2000.between(*ra)
_id = df.DELTA_J2000.between(*dec)
_sel = _ir & _id
df_sample = df.loc[_sel]

# %%
ds_label = p.add_dataset(df_sample,label='little_square',x='ALPHA_J2000',y='DELTA_J2000')
p.plot(ds_label)
p.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3a224bba-8193-485d-b667-8d8972be0aad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3a224bba-8193-485d-b667-8d8972be0aad");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3a224bba-8193-485d-b667-8d8972be0aad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '
type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"}},"id":"8d0e250f-fb27-467d-821e-9d1ee8560118","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c0a71c1c-87f1-4453-aea0-b328e94c0d73","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c42856c8-ba2a-4fc2-b1ca-1a8f57823cde","type":"ColumnDataSource"},"glyph":{"id":"97ea8285-ef7a-41db-983c-88c826eeb58f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonsel ...

# %% [markdown]
# ## Shift sub-sample position
#
# Eventually, we'll x-match the objects of "sample" with their neighbors; because we want to assess the typical distance within *CS82* objects we will crossmatch the same catalog on each side.
# Clearly we cannot steady match those objects, otherwise objects will all match themselves, at distance zero; we need to shift them from a certain amount.
#
# What we'll to do now is to shift all the objects in "sample" to another region of the plot where the density is uniform.
# This way

# %%
ra_s = (-35,-30)
dec_s= (-1,0)
#region = zip(ra,dec)
xc = (ra_s[1]-ra_s[0])/2 + ra_s[0]
yc = (dec_s[1]-dec_s[0])/2 + dec_s[0]
xl = ra_s[1]-ra_s[0]
yl = dec_s[1]-dec_s[0]
region = dict(center=(xc,yc),sides=(xl,yl))
reg_label = p.add_region(region,label='counter region')
p.plot(reg_label)
p.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b746cbc2-1331-4204-9745-9bd6e3d6d41e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b746cbc2-1331-4204-9745-9bd6e3d6d41e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b746cbc2-1331-4204-9745-9bd6e3d6d41e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b746cbc2-1331-4204-9745-9bd6e3d6d41e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7e850c47-8f02-4fa8-8be0-e29f00918a8b":{"roots":{"references":[{"attributes":{},"id":"c2c9512e-a15d-4e3c-b6fc-5dcca1706e9e","type":"LinearScale"},{"attributes":{"data_source":{"id":"96d5e8c8-2220-48a3-8a22-c379df1a3255","type":"ColumnDataSource"},"glyph":{"id":"18935486-e312-40df-8fbc-2ddc8d2e36a3","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"83c16949-9860-4a3f-ab14-2df662ec9bdc","type":"Circle"},"selection_glyph":null},"id":"590ef554-a8f0-4d69-a701-9771cc6223d3","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"46eee365-3f8a-4741-8daa-81639a18ff99","type":"PanTool"},{"id":"a1955711-8c44-4404-b33c-5b1e29d300d5","type":"BoxZoomTool"},{"id":"7599db2d-67ed-446d-9409-f96870b4098f","type":"WheelZoomTool"},{"id":"c559a626-21aa-4d4c-bfbc-c1fce5f8c97c","type":"ResizeTool"},{"id":"63f4a257-1f7b-4909-a753-983fd0e27523","type":"ResetTool"},{"id":"ee3ce111-a30c-4181-b393-67d9ff5f320b","type":"BoxSelectTool"},{"id":"8d8f5a58-8e00-4d9f-8bdd-dbb0725c8faa","type":"LassoSelectTool"},{"id":"298cd2fc-cb9e-4d12-ad0b-087166e5afec","type":"SaveTool"},{"id":"14845633-dfcd-4664-8847-2be0f977e367","type":"HelpTool"}]},"id":"426d1f1b-0398-4a9e-92c1-f93cf927534c","type":"Toolbar"},{"attributes":{"callback":null},"id":"412b347f-b92e-421a-b139-70290400d709","type":"DataRange1d"},{"attributes":{},"id":"e62a4d67-ffed-42c2-ae85-06235e08dca9","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"ra"},"y":{"field":"dec"}},"id":"0d86b0c7-a04b-4880-a24a-1ae4ab8b2f1d","type":"Circle"},{"attributes":{},"id":"4ac1ba35-b2ec-4eb4-a249-e90271764202","type":"LinearScale"},{"attributes":{"axis_label":"ra","formatter":{"id":"4fc0749a-2ff7-452d-a246-b49a87761919","type":"BasicTickFormatter"},"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"}},"id":"a521d865-a0d3-4ef3-8bc0-ae7d2b8dd1b6","type":"LinearAxis"},{"attributes":{},"id":"4fc0749a-2ff7-452d-a246-b49a87761919","type":"BasicTickFormatter"},{"attributes":{},"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"},{"attributes":{"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"}},"id":"b4f28d54-6f43-44a5-b6c5-6203fa2e2f25","type":"Grid"},{"attributes":{},"id":"60ad5e1d-f21d-4362-a848-80d674c3837f","type":"ToolEvents"},{"attributes":{"axis_label":"dec","formatter":{"id":"e62a4d67-ffed-42c2-ae85-06235e08dca9","type":"BasicTickFormatter"},"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"}},"id":"73edb850-e0b0-486f-847c-2ddb729dc4b5","type":"LinearAxis"},{"attributes":{},"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"84b153b6-da62-4a42-9a35-6493a6207945","type":"BasicTicker"}},"id":"8d0e250f-fb27-467d-821e-9d1ee8560118","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c0a71c1c-87f1-4453-aea0-b328e94c0d73","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c42856c8-ba2a-4fc2-b1ca-1a8f57823cde","type":"ColumnDataSource"},"glyph":{"id":"97ea8285-ef7a-41db-983c-88c826eeb58f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonsel ...

# %%
# EXTRACTED BOKEH-SELECTED POINTS FROM PLOT

# %%
ra_center_sample = ra[0] + (ra[1] - ra[0])/2
dec_center_sample = dec[0] + (dec[1] - dec[0])/2
ra_shift = xc - ra_center_sample
dec_shift = yc - dec_center_sample
print('Shift position: RA:{} ; Dec:{}'.format(ra_shift,dec_shift))
# Out:
# Shift position: RA:-35.0 ; Dec:-1.0

# %%
df_shift = df_sample.copy()
df_shift.ALPHA_J2000 = df_sample.ALPHA_J2000 + ra_shift
df_shift.DELTA_J2000 = df_sample.DELTA_J2000 + dec_shift
df_shift.describe()
# Out:
#               OBJID  ALPHA_J2000  DELTA_J2000    MAG_AUTO  MAGERR_AUTO  \
# count  2.560000e+02   256.000000   256.000000  256.000000   256.000000
# mean   1.223465e+07   -32.620157    -0.539295   23.470467     0.112069
# std    2.882092e+06     1.411306     0.264736    1.457863     0.070940
# min    7.409026e+06   -34.977540    -0.999489   18.151360     0.001116
# 25%    9.672469e+06   -33.831197    -0.755851   22.863778     0.050357
# 50%    1.187874e+07   -32.579358    -0.541875   23.780987     0.110617
# 75%    1.535903e+07   -31.459735    -0.315408   24.484078     0.162663
# max    1.558138e+07   -30.041352    -0.065046   25.805803     0.312472
#
#        CLASS_STAR  FLUX_RADIUS       FLAGS
# count  256.000000   256.000000  256.000000
# mean     0.258787     2.900509    0.347656
# std      0.292045     1.304429    0.907612
# min      0.000126     1.253912    0.000000
# 25%      0.020178     2.164235    0.000000
# 50%      0.086092     2.607055    0.000000
# 75%      0.497105     3.422127    0.000000
# max      0.996736    15.919291    3.000000
#
# Total number of rows: 256 (2.6e+02)
#
# -> Has Nil? (How many?)
# OBJID          0
# ALPHA_J2000    0
# DELTA_J2000    0
# MAG_AUTO       0
# MAGERR_AUTO    0
# CLASS_STAR     0
# FLUX_RADIUS    0
# FLAGS          0
# dtype: int64

# %%
_ir = df.ALPHA_J2000.between(*ra_s)
_id = df.DELTA_J2000.between(*dec_s)
_sel = _ir & _id
df_counter = df.loc[_sel]
df_counter.describe()
# Out:
#               OBJID  ALPHA_J2000  DELTA_J2000    MAG_AUTO  MAGERR_AUTO  \
# count  3.470000e+02   347.000000   347.000000  347.000000   347.000000
# mean   3.890520e+06   -32.539351    -0.511057   23.411972     0.105416
# std    4.085083e+05     1.405469     0.278071    1.622708     0.075399
# min    3.140234e+06   -34.971781    -0.995969   17.783897     0.000652
# 25%    3.527720e+06   -33.701883    -0.749582   22.622023     0.038822
# 50%    3.931886e+06   -32.720679    -0.519132   23.800619     0.096666
# 75%    4.320219e+06   -31.372246    -0.279213   24.672006     0.163996
# max    4.615349e+06   -30.011974    -0.000758   25.935667     0.307629
#
#        CLASS_STAR  FLUX_RADIUS       FLAGS
# count  347.000000   347.000000  347.000000
# mean     0.341926     2.733551    0.345821
# std      0.345323     1.316458    0.877631
# min      0.000133     0.990985    0.000000
# 25%      0.022910     1.904746    0.000000
# 50%      0.195239     2.417965    0.000000
# 75%      0.635009     3.086980    0.000000
# max      0.993113    13.340192    3.000000
#
# Total number of rows: 347 (3.5e+02)
#
# -> Has Nil? (How many?)
# OBJID          0
# ALPHA_J2000    0
# DELTA_J2000    0
# MAG_AUTO       0
# MAGERR_AUTO    0
# CLASS_STAR     0
# FLUX_RADIUS    0
# FLAGS          0
# dtype: int64

# %%
ds_label = p.add_dataset(df_counter,label='counter_square',x='ALPHA_J2000',y='DELTA_J2000')
p.plot(ds_label)
p.show()
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"ra"},"y":{"field":"dec"}},"id":"0d86b0c7-a04b-4880-a24a-1ae4ab8b2f1d","type":"Circle"},{"attributes":{"data_source":{"id":"bc49b0dd-699e-4097-b43b-7d73f92c7b91","type":"ColumnDataSource"},"glyph":{"id":"b725139c-edfe-4ca0-b9e5-c9d08ae649ae","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c01af73a-22c0-4f11-9fe5-23fcf95e51f6","type":"Circle"},"selection_glyph":null},"id":"6688b2cc-11e2-45e1-a604-02be87186bbc","type":"GlyphRenderer"},{"attributes":{},"id":"4ac1ba35-b2ec-4eb4-a249-e90271764202","type":"LinearScale"},{"attributes":{"axis_label":"ra","formatter":{"id":"4fc0749a-2ff7-452d-a246-b49a87761919","type":"BasicTickFormatter"},"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"}},"id":"a521d865-a0d3-4ef3-8bc0-ae7d2b8dd1b6","type":"LinearAxis"},{"attributes":{"data_source":{"id":"d2c5b530-bf20-4ef1-ac8f-9685b36339d7","type":"ColumnDataSource"},"glyph":{"id":"d94bda99-dd16-4ef4-86e5-ce2f8e552fb9","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"10cb2ce1-1bc6-407e-acb5-0a2098e68f2c","type":"Circle"},"selection_glyph":null},"id":"2fccf119-785b-4430-9eb1-d0527489d7c9","type":"GlyphRenderer"},{"attributes":{},"id":"4fc0749a-2ff7-452d-a246-b49a87761919","type":"BasicTickFormatter"},{"attributes":{},"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"},{"attributes":{"plot":{"id":"28273999-eaa1-4657-b7c1-7436801e377a","subtype":"Figure","type":"Plot"},"ticker":{"id":"468727dd-4f1b-4d27-8337-763292174a51","type":"BasicTicker"}},"id":"b4f28d54-6f43-44a5-b6c5-6203fa2e2f25","type":"Grid"},{"attributes":{},"id":"60ad5e1d-f21d-4362-a848-80d674c3837f","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"ra"},"y":{"field":"dec"}},"id":"c01af73a-22c0-4f11-9fe5-23fcf95e51f6","ty ...

# %% [markdown]
# ## X-Match
#
# Now the time to actually cross-match the samples has arrived.

# %%
from booq.pipelines import xmatch

# %% [markdown]
# ### Nearest Neighbour
#
# We should apply the nearest-neighbor first hand and see how the matching distances plot.
# I suspect that the distances-distribution will show a peak somewhere between the objects mean position error and the typical value --if there is-- to objects separation.

# %%
columns = dict(ra='ALPHA_J2000', dec='DELTA_J2000', id='OBJID')
df_match = xmatch.xmatch(df_shift, df_counter,
                         columns_A=columns, columns_B=columns,
                         method='nn')
df_match.describe()
# Out:
# /home/chbrandt/.conda/envs/booq/lib/python3.6/site-packages/pandas/core/indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/chbrandt/.conda/envs/booq/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                   A                                                  \
#               OBJID ALPHA_J2000 DELTA_J2000    MAG_AUTO MAGERR_AUTO
# count  2.560000e+02  256.000000  256.000000  256.000000  256.000000
# mean   1.223465e+07  -32.620157   -0.539295   23.470467    0.112069
# std    2.882092e+06    1.411306    0.264736    1.457863    0.070940
# min    7.409026e+06  -34.977540   -0.999489   18.151360    0.001116
# 25%    9.672469e+06  -33.831197   -0.755851   22.863778    0.050357
# 50%    1.187874e+07  -32.579358   -0.541875   23.780987    0.110617
# 75%    1.535903e+07  -31.459735   -0.315408   24.484078    0.162663
# max    1.558138e+07  -30.041352   -0.065046   25.805803    0.312472
#
#                                                       B              \
#        CLASS_STAR FLUX_RADIUS       FLAGS         OBJID ALPHA_J2000
# count  256.000000  256.000000  256.000000  1.340000e+02  134.000000
# mean     0.258787    2.900509    0.347656  3.934047e+06  -32.649369
# std      0.292045    1.304429    0.907612  4.042531e+05    1.395390
# min      0.000126    1.253912    0.000000  3.262228e+06  -34.958351
# 25%      0.020178    2.164235    0.000000  3.551742e+06  -33.820636
# 50%      0.086092    2.607055    0.000000  3.939801e+06  -32.760920
# 75%      0.497105    3.422127    0.000000  4.346347e+06  -31.506022
# max      0.996736   15.919291    3.000000  4.613416e+06  -30.031077
#
#                                                                                \
#       DELTA_J2000    MAG_AUTO MAGERR_AUTO  CLASS_STAR FLUX_RADIUS       FLAGS
# count  134.000000  134.000000  134.000000  134.000000  134.000000  134.000000
# mean    -0.519543   23.555225    0.113413    0.316931    2.658173    0.253731
# std      0.275426    1.455173    0.075825    0.331881    1.019825    0.742750
# min     -0.984794   19.408167    0.002176    0.000133    0.990985    0.000000
# 25%     -0.742123   22.855353    0.052740    0.027214    1.933454    0.000000
# 50%     -0.523716   23.871141    0.114776    0.129257    2.519496    0.000000
# 75%     -0.287598   24.632201    0.169650    0.593842    2.997311    0.000000
# max     -0.000758   25.935667    0.307629    0.992559    8.257999    3.000000
#
#                AB
#              dist
# count  134.000000
# mean     0.046076
# std      0.025767
# min      0.005776
# 25%      0.027304
# 50%      0.041942
# 75%      0.062863
# max      0.120303
#
# Total number of rows: 390 (3.9e+02)
#
# -> Has Nil? (How many?)
# A   OBJID          134
#     ALPHA_J2000    134
#     DELTA_J2000    134
#     MAG_AUTO       134
#     MAGERR_AUTO    134
#     CLASS_STAR     134
#     FLUX_RADIUS    134
#     FLAGS          134
# B   OBJID          256
#     ALPHA_J2000    256
#     DELTA_J2000    256
#     MAG_AUTO       256
#     MAGERR_AUTO    256
#     CLASS_STAR     256
#     FLUX_RADIUS    256
#     FLAGS          256
# AB  dist           256
# dtype: int64

# %%
from bokeh.io import show

from booq.plot import PlotHisto
p = PlotHisto()
ds_label = p.add_dataset(df_match,label='distances',x=('AB','dist'))
p.plot(ds_label)
p.show()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="933a9117-6835-4864-888e-d9b5efaebca8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08581040-4a32-41cd-b66b-157a3d9adde1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById
type":"Figure","type":"Plot"}},"id":"850e8c70-5e82-4054-b80a-42a9dad2ce24","type":"PanTool"},{"attributes":{"plot":{"id":"40f3db33-5246-46f2-a935-bd00dce6c93a","subtype":"Figure","type":"Plot"}},"id":"542dc6f3-f395-4ea5-9af6-ce4b4ffdaa30","type":"HelpTool"},{"attributes":{},"id":"ce9c8e01-f083-472f-b4e3-c1dcbb0365bf","type":"LinearScale"},{"attributes":{"plot":null,"text":""},"id":"98ebd5a7-578b-4394-bd6b-49aa7fcd28f6","type":"Title"},{"attributes":{"data_source":{"id":"79baec4e-2254-4817-83f5-daf0cd111abf","type":"ColumnDataSource"},"glyph":{"id":"d20dca1a-59f9-4977-b08d-a0686b560ae3","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3aa9c87c-bb9d-43e6-ac73-3ee5c10dd63a","type":"Quad"},"selection_glyph":null},"id":"8fdbd71d-f392-40ed-876e-387e50d4f33a","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"82f92fa3-7789-4806-94e0-b1377139486e","type":"LinearAxis"}],"left":[{"id":"bbe8675a-0e20-4e5b-8d22-a96414a6c229","type":"LinearAxis"}],"renderers":[{"id":"82f92fa3-7789-4806-94e0-b137 ...

# %% [markdown]
# ### Great Circle

# %%
from astropy import units
r = 0.1 * units.degree

columns = dict(ra='ALPHA_J2000', dec='DELTA_J2000', id='OBJID')
df_match = xmatch.xmatch(df_shift, df_counter,
                         columns_A=columns, columns_B=columns,
                         method='gc', radius=r)
# Out:
# /home/chbrandt/.conda/envs/booq/lib/python3.6/site-packages/pandas/core/indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/chbrandt/.conda/envs/booq/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_match.describe()
# Out:
#                    A                                                  \
#                OBJID ALPHA_J2000 DELTA_J2000    MAG_AUTO MAGERR_AUTO
# count   2.560000e+02  256.000000  256.000000  256.000000  256.000000
# unique           NaN         NaN         NaN         NaN         NaN
# top              NaN         NaN         NaN         NaN         NaN
# freq             NaN         NaN         NaN         NaN         NaN
# mean    1.223465e+07  -32.620157   -0.539295   23.470467    0.112069
# std     2.882092e+06    1.411306    0.264736    1.457863    0.070940
# min     7.409026e+06  -34.977540   -0.999489   18.151360    0.001116
# 25%     9.672469e+06  -33.831197   -0.755851   22.863778    0.050357
# 50%     1.187874e+07  -32.579358   -0.541875   23.780987    0.110617
# 75%     1.535903e+07  -31.459735   -0.315408   24.484078    0.162663
# max     1.558138e+07  -30.041352   -0.065046   25.805803    0.312472
#
#                                                        B              \
#         CLASS_STAR FLUX_RADIUS       FLAGS         OBJID ALPHA_J2000
# count   256.000000  256.000000  256.000000  2.220000e+02  222.000000
# unique         NaN         NaN         NaN           NaN         NaN
# top            NaN         NaN         NaN           NaN         NaN
# freq           NaN         NaN         NaN           NaN         NaN
# mean      0.258787    2.900509    0.347656  3.931571e+06  -32.612756
# std       0.292045    1.304429    0.907612  4.080172e+05    1.398094
# min       0.000126    1.253912    0.000000  3.262228e+06  -34.958351
# 25%       0.020178    2.164235    0.000000  3.568243e+06  -33.822787
# 50%       0.086092    2.607055    0.000000  3.937109e+06  -32.618068
# 75%       0.497105    3.422127    0.000000  4.341395e+06  -31.478739
# max       0.996736   15.919291    3.000000  4.604678e+06  -30.031077
#
#                                                                     \
#        DELTA_J2000    MAG_AUTO MAGERR_AUTO  CLASS_STAR FLUX_RADIUS
# count   222.000000  222.000000  222.000000  222.000000  222.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean     -0.526743   23.638939    0.114387    0.301442    2.666440
# std       0.260890    1.332290    0.070706    0.322037    0.974532
# min      -0.984794   19.408167    0.002176    0.000133    0.990985
# 25%      -0.739042   22.866571    0.055755    0.020551    1.958735
# 50%      -0.523367   23.931927    0.119008    0.125565    2.509756
# 75%      -0.305987   24.632629    0.167119    0.594300    3.004147
# max      -0.044297   25.935667    0.307629    0.992559    8.257999
#
#                             AB
#              FLAGS        dist duplicates
# count   222.000000  222.000000        159
# unique         NaN         NaN        137
# top            NaN         NaN    3290017
# freq           NaN         NaN          3
# mean      0.265766    0.053477        NaN
# std       0.746999    0.024330        NaN
# min       0.000000    0.005776        NaN
# 25%       0.000000    0.035120        NaN
# 50%       0.000000    0.050715        NaN
# 75%       0.000000    0.072395        NaN
# max       3.000000    0.099972        NaN
#
# Total number of rows: 478 (4.8e+02)
#
# -> Has Nil? (How many?)
# A   OBJID          222
#     ALPHA_J2000    222
#     DELTA_J2000    222
#     MAG_AUTO       222
#     MAGERR_AUTO    222
#     CLASS_STAR     222
#     FLUX_RADIUS    222
#     FLAGS          222
# B   OBJID          256
#     ALPHA_J2000    256
#     DELTA_J2000    256
#     MAG_AUTO       256
#     MAGERR_AUTO    256
#     CLASS_STAR     256
#     FLUX_RADIUS    256
#     FLAGS          256
# AB  dist           256
#     duplicates     319
# dtype: int64

# %%
print(df_match)
# Out:
#                A                                                            \
#            OBJID ALPHA_J2000 DELTA_J2000   MAG_AUTO MAGERR_AUTO CLASS_STAR
# 1            NaN         NaN         NaN        NaN         NaN        NaN
# 2            NaN         NaN         NaN        NaN         NaN        NaN
# 3            NaN         NaN         NaN        NaN         NaN        NaN
# 5            NaN         NaN         NaN        NaN         NaN        NaN
# 6            NaN         NaN         NaN        NaN         NaN        NaN
# 8            NaN         NaN         NaN        NaN         NaN        NaN
# 9            NaN         NaN         NaN        NaN         NaN        NaN
# 10           NaN         NaN         NaN        NaN         NaN        NaN
# 11           NaN         NaN         NaN        NaN         NaN        NaN
# 12           NaN         NaN         NaN        NaN         NaN        NaN
# 13           NaN         NaN         NaN        NaN         NaN        NaN
# 14           NaN         NaN         NaN        NaN         NaN        NaN
# 15           NaN         NaN         NaN        NaN         NaN        NaN
# 16           NaN         NaN         NaN        NaN         NaN        NaN
# 17           NaN         NaN         NaN        NaN         NaN        NaN
# 18           NaN         NaN         NaN        NaN         NaN        NaN
# 19           NaN         NaN         NaN        NaN         NaN        NaN
# 20           NaN         NaN         NaN        NaN         NaN        NaN
# 21           NaN         NaN         NaN        NaN         NaN        NaN
# 22           NaN         NaN         NaN        NaN         NaN        NaN
# 23           NaN         NaN         NaN        NaN         NaN        NaN
# 8894    2.960883   0.0        NaN         NaN         NaN        NaN
# 8895    4.410846   0.0        NaN         NaN         NaN        NaN
# 8896    4.821545   0.0        NaN         NaN         NaN        NaN
# 8899    3.764904   0.0        NaN         NaN         NaN        NaN
# 8900    2.506099   0.0        NaN         NaN         NaN        NaN
# 8901    3.965923   3.0        NaN         NaN         NaN        NaN
# 8902    2.708654   0.0        NaN         NaN         NaN        NaN
# 8903    2.064444   0.0        NaN         NaN         NaN        NaN
# 8905   15.919291   3.0        NaN         NaN         NaN        NaN
# 8907    1.685441   0.0        NaN         NaN         NaN        NaN
# 8908    3.215640   3.0        NaN         NaN         NaN        NaN
# 8909    4.594835   0.0        NaN         NaN         NaN        NaN
# 8910    2.223318   0.0        NaN         NaN         NaN        NaN
# 8912    2.046458   0.0        NaN         NaN         NaN        NaN
#
#                                                      AB  \
#      MAGERR_AUTO CLASS_STAR FLUX_RADIUS FLAGS      dist
# 1       0.055147   0.051977    3.460367   0.0  0.081861
# 2       0.009016   0.060723    3.435789   0.0  0.048664
# 3       0.009016   0.060723    3.435789   0.0  0.046036
# 5       0.119511   0.003128    3.762184   0.0  0.035858
# 6       0.019146   0.062210    4.069480   3.0  0.099455
# 8       0.083677   0.055416    4.887821   2.0  0.070841
# 9       0.146886   0.721400    1.659484   0.0  0.013316
# 10      0.083677   0.055416    4.887821   2.0  0.048705
# 11      0.019146   0.062210    4.069480   3.0  0.098287
# 12      0.146886   0.721400    1.659484   0.0  0.064529
# 13      0.146886   0.721400    1.659484   0.0  0.074795
# 14      0.004894   0.978813    2.732230   0.0  0.037248
# 15      0.083677   0.055416    4.887821   2.0  0.070028
# 16      0.057429   0.300195    3.190158   0.0  0.050860
# 17      0.063803   0.408649    2.927332   0.0  0.023906
# 18      0.063803   0.408649    2.927332   0.0  0.034210
# 19      0.067466   0.119055    3.190311   0.0  0.013012
# 20      0.167119   0.637481    1.958735   0.0  0.060828
# 21      0.167119   0.637481    1.958735   0.0  0.010884
# 22      0.167119   0.637481    1.958735   0.0  0.070704
# 23      0.049756   0.072852    4.243998   0.0  0.025843
# 24      0.038240   0.118525    2.976801   0.0  0.095130
# 25      0.041375   0.031503    3.588953   0.0  0.098719
# 26      0.167119   0.637481    1.958735   0.0  0.064407
# 27      0.098140   0.256821    4.567374   0.0  0.049624
# 28      0.038240   0.118525    2.976801   0.0  0.051316
# 29      0.041375   0.031503    3.588953   0.0  0.079708
# 30      0.231067   0.089996    2.528562   0.0  0.070673
# 32      0.055710   0.740673    2.527456   0.0  0.026140
# 35      0.055710   0.740673    2.527456   0.0  0.073443
# ...          ...        ...         ...   ...       ...
# 8873         NaN        NaN         NaN   NaN       NaN
# 8874         NaN        NaN         NaN   NaN       NaN
# 8875         NaN        NaN         NaN   NaN       NaN
# 8876         NaN        NaN         NaN   NaN       NaN
# 8879         NaN        NaN         NaN   NaN       NaN
# 8880         NaN        NaN         NaN   NaN       NaN
# 8881         NaN        NaN         NaN   NaN       NaN
# 8882         NaN        NaN         NaN   NaN       NaN
# 8884         NaN        NaN         NaN   NaN       NaN
# 8885         NaN        NaN         NaN   NaN       NaN
# 8888         NaN        NaN         NaN   NaN       NaN
# 8889         NaN        NaN         NaN   NaN       NaN
# 8890         NaN        NaN         NaN   NaN       NaN
# 8891         NaN        NaN         NaN   NaN       NaN
# 8892         NaN        NaN         NaN   NaN       NaN
# 8893         NaN        NaN         NaN   NaN       NaN
# 8894         NaN        NaN         NaN   NaN       NaN
# 8895         NaN        NaN         NaN   NaN       NaN
# 8896         NaN        NaN         NaN   NaN       NaN
# 8899         NaN        NaN         NaN   NaN       NaN
# 8900         NaN        NaN         NaN   NaN       NaN
# 8901         NaN        NaN         NaN   NaN       NaN
# 8902         NaN        NaN         NaN   NaN       NaN
# 8903         NaN        NaN         NaN   NaN       NaN
# 8905         NaN        NaN         NaN   NaN       NaN
# 8907         NaN        NaN         NaN   NaN       NaN
# 8908         NaN        NaN         NaN   NaN       NaN
# 8909         NaN        NaN         NaN   NaN       NaN
# 8910         NaN        NaN         NaN   NaN       NaN
# 8912         NaN        NaN         NaN   NaN       NaN
#
#
#                            duplicates
# 1                                None
# 2                                None
# 3                                None
# 5                             4322070
# 6                                None
# 8                             4561734
# 9                             4339674
# 10                            4561734
# 11                               None
# 12                               None
# 13                               None
# 14                    4562437;4566157
# 15                    4561734;4569374
# 16                            4560552
# 17                               None
# 18                               None
# 19            4568791;4579915;4581289
# 20                            4581289
# 21                               None
# 22                               None
# 23    4577453;4581289;4587246;4588417
# 24                               None
# 25                               None
# 26                               None
# 27            4579915;4590075;4596667
# 28                               None
# 29                               None
# 30                            4590752
# 32    4598907;4599845;4602097;4606730
# 35                    4602097;4606730
# ...                               ...
# 8873                              NaN
# 8874                              NaN
# 8875                              NaN
# 8876                              NaN
# 8879                              NaN
# 8880                              NaN
# 8881                              NaN
# 8882                              NaN
# 8884                              NaN
# 8885                              NaN
# 8888                              NaN
# 8889                              NaN
# 8890                              NaN
# 8891                              NaN
# 8892                              NaN
# 8893                              NaN
# 8894                              NaN
# 8895                              NaN
# 8896                              NaN
# 8899                              NaN
# 8900                              NaN
# 8901                              NaN
# 8902                              NaN
# 8903                              NaN
# 8905                              NaN
# 8907                              NaN
# 8908                              NaN
# 8909                              NaN
# 8910                              NaN
# 8912                              NaN
#
# [478 rows x 18 columns]

# %%
from bokeh.io import show

from booq.plot import PlotHisto
p = PlotHisto()
ds_label = p.add_dataset(df_match,label='distances',x=('AB','dist'))
p.plot(ds_label)
p.show()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11967af0-c786-432c-8707-2c1aa7fa10e1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e9a6b4fb-5cdf-4a9b-b06b-14bcf6d4ee02"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e9a6b4fb-5cdf-4a9b-b06b-14bcf6d4ee02");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e9a6b4fb-5cdf-4a9b-b06b-14bcf6d4ee02");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e9a6b4fb-5cdf-4a9b-b06b-14bcf6d4ee02' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a1dd8124-2014-4347-b958-68a87a455d04":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":
type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e0a8defd-7cdb-4582-a98f-f604ff4fb338","subtype":"Figure","type":"Plot"}},"id":"e8ed8d83-1636-41d4-ba7a-6f5c74d4570e","type":"HelpTool"},{"attributes":{"callback":null},"id":"7d035280-9233-4d0f-ba05-dfee279bc86f","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"bf93035f-f4d9-4452-8663-ac8bdfd0c9f8","type":"Title"},{"attributes":{"below":[{"id":"7f0a87c6-5164-4864-97d1-5b19fae31959","type":"LinearAxis"}],"left":[{"id":"d8215826-1e17-497c-8c8b-55d443bed0d7","type":"LinearAxis"}],"renderers":[{"id":"7f0a87c6-5164-4864-97d1-5b19fae31959","type":"LinearAxis"},{"id":"6d4eec4d-63c9-4abd-8288-a328135137f4","type":"Grid"},{"id":"d8215826-1e17-497c-8c8b-55d443bed0d7","type":"LinearAxis"},{"id":"72c68130-090b-44f4-9aee-da0640b7e80a","type":"Grid"},{"id":"b6072fa0-6559-493d-9dda-4f0632d50d2d","type":"BoxAnnotation"},{"id":"c6efb031-704d-43e8-8449-ea4f1f326d9a","type":"Legend"},{"id":"f41b2e01-0b68-402b-be5f-cebbb6e5e23a","type":" ...

# %% [markdown]
# ## KNN
#
# Out of curiosity, let us compute the typical, or *mean* distance between the first `k` neighbours of each object in the catalog; the entire catalog.
#
#
# In fact, I want to know the average distance of the first neighbour; although, `k=2` will be used because we are going to match the catalog with itself.

# %%
from sklearn.neighbors import NearestNeighbors

X = df[['ALPHA_J2000','DELTA_J2000']].values
nbrs = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(X)
distances, indices = nbrs.kneighbors(X)

# %%
dists = distances.transpose()

# %%
from bokeh.io import show

from booq.plot import PlotHisto
p = PlotHisto()
ds_label = p.add_dataset(dists,label='1st-neighbour distances',x=1)
p.plot(ds_label)
ds_label = p.add_dataset(dists,label='2nd-neighbour distances',x=2)
p.plot(ds_label)
p.show()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f88803c7-f1fd-465b-8472-587f1acffc9b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8f1c28d0-5b7b-4901-b4cc-219f43d640e2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8f1c28d0-5b7b-4901-b4cc-219f43d640e2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8f1c28d0-5b7b-4901-b4cc-219f43d640e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8f1c28d0-5b7b-4901-b4cc-219f43d640e2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a94a2fe3-3674-48cd-b73a-fbd07bbc3979":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"a532d26c-2257-4be0-a726-c8539d9f727a","type":"Quad"},{"attributes":{"below":[{"id":"cf264748-7de7-438e-abe2-72e7fcdcd38c","type":"LinearAxis"}],"left":[{"id":"7f8e8900-6d95-4023-b268-85483088d122","type":"LinearAxis"}],"renderers":[{"id":"cf264748-7de7-438e-abe2-72e7fcdcd38c","type":"LinearAxis"},{"id":"9956dce8-bd3f-4b2b-a06e-91e918225892","type":"Grid"},{"id":"7f8e8900-6d95-4023-b268-85483088d122","type":"LinearAxis"},{"id":"54c7040d-46cc-4700-9dbb-f97cc49cff2f","type":"Grid"},{"id":"1e82777e-13f6-496c-9f09-1bae767386b7","type":"BoxAnnotation"},{"id":"8665dd6c-8511-4f7b-93e8-61ffcb8d9c0b","type":"Legend"},{"id":"3a327f96-9cf9-40a7-b759-52a0e1d7d919","type":"GlyphRenderer"},{"id":"9cfabbff-c637-47a7-aa4b-81d9969bb9d7","type":"GlyphRenderer"}],"title":{"id":"d8c7477b-d608-4e0d-b036-a11fe0ee5922","type":"Title"},"tool_events":{"id":"55b5c00f-501f-4146-b18b-87cdcbcf3831","type":"ToolEvents"},"toolbar":{"id":"4d46bfe4-a67d-4de2-ba60-21764c901b58","type":"Toolbar"},"x_range":{"id":"30a0f06d-8431-468d-ba41-1785f6616cfd","type":"DataRange1d"},"x_scale":{"id":"01c86f9d-101a-4028-8092-a7da984db25c","type":"LinearScale"},"y_range":{"id":"970c5c87-d1da-4b94-81fa-be3bb0d45526","type":"DataRange1d"},"y_scale":{"id":"157e7ea4-130f-4d1f-a71f-75af26505abb","type":"LinearScale"}},"id":"ed1700ca-bb3a-4d0a-b54b-da2086bb362e","subtype":"Figure","type":"Plot"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"#23888D"},"left":{"field":"left"},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"9202db3c-f36d-4a16-9ae1-88466095656f","type":"Quad"},{"attributes":{"plot":{"id":"ed1700ca-bb3a-4d0a-b54b-da2086bb362e","subtype":"Figure","type":"Plot"}},"id":"87c251d2-717c-49ce-8dc9-acbec9c8f654","type":"ResetTool"},{"attributes":{"data_source":{"id":"673276c3-85ef-49b6-8ed0-c14ce3ac5b57","type":"ColumnDataSource"},"glyph":{"id":"9202db3c-f36d-4a16-9ae1-88466095656f","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a532d26c-2257-4be0-a726-c8539d9f727a","type":"Quad"},"selection_glyph":null},"id":"3a327f96-9cf9-40a7-b759-52a0e1d7d919","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ed1700ca-bb3a-4d0a-b54b-da2086bb362e","subtype":"Figure","type":"Plot"}},"id":"b4e43f26-d531-47ba-b139-33768c84714f","type":"HelpTool"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"#1F114B"},"left":{"field":"left"},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"68694bb3-fb65-4e6b-8309-e939a836807f","type":"Quad"},{"attributes":{"callback":null},"id":"30a0f06d-8431-468d-ba41-1785f6616cfd","type":"DataRange1d"},{"attributes":{"label":{"value":"bins"},"renderers":[{"id":"3a327f96-9cf9-40a7-b759-52a0e1d7d919","type":"GlyphRenderer"},{"id":"9cfabbff-c637-47a7-aa4b-81d9969bb9d7","type":"GlyphRenderer"}]},"id":"56e57433-0015-4fd7-8bd0-080ec70d2aa2","type":"LegendItem"},{"attributes":{"data_source":{"id":"f6ce2017-d1a9-494e-bf6d-75deba30d1cc","type":"ColumnDataSource"},"glyph":{"id":"68694bb3-fb65-4e6b-8309-e939a836807f","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a90b3ac9-612b-4768-987f-2a7f3b801968","type":"Quad"},"selection_glyph":null},"id":"9cfabbff-c637-47a7-aa4b-81d9969bb9d7","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"ed1700ca-bb3a-4d0a-b54b-da2086bb362e","subtype":"Figure","type":"Plot"}},"id":"22d98e3e-1fbb-41fa-a660-7f787fb2a3e6","type":"ResizeTool"},{"attributes":{},"id":"55b5c00f-501f-4146-b18b-87cdcbcf3831","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_t ...

# %% [markdown]
# #TODO:
# * plot legend: WRONG and missing labels; labels should be the name/label given to `add_dataset`
# * plot axes: x-axis label is missing; axis label should be either the `x` argument --if--, or the default: "bins"
